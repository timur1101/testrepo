# %% [markdown]
# ## 📝 Домашнее задание
#
# **Задача:** Постройте мини-систему «Умный ассистент по документам с визуальным поиском»:
#
# **RAG часть:**
# 1. Возьмите любую статью на английском (Wikipedia, новости) и разбейте на чанки
# 2. Проиндексируйте через FAISS и задайте минимум 5 вопросов
# 3. Сравните ответы: LLM без контекста vs LLM с RAG
# 4. Найдите пример где RAG помог избежать галлюцинации
#
# **Multimodal часть:**
# 1. Загрузите 2-3 своих изображения (или из интернета)
# 2. Попросите Gemma-3 описать каждое с разными системными промптами (например: «ты фотограф», «ты учитель», «ты маркетолог»)
# 3. Проведите мини-диалог (минимум 3 хода) об одном изображении
#
# **Сдать:** ноутбук с кодом + 3-4 предложения выводов: что вас удивило, где RAG не справился, насколько точны ответы Gemma-3.
